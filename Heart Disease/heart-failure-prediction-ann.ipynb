# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from keras import callbacks
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %%
#loading data
data = pd.read_csv("heart_failure_clinical_records_dataset.csv")
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
cols= ["#800080","#FF7F50"]
sns.countplot(x= data["DEATH_EVENT"], palette= cols)
# Out:
# <AxesSubplot:xlabel='DEATH_EVENT', ylabel='count'>

# %% [markdown]
# Point to note is that there is an imbalance in the data.

# %%
cmap = sns.diverging_palette(266,10,  s=99, l=50, n=9)
corrmat = data.corr()
plt.subplots(figsize=(18,18))
sns.heatmap(corrmat,cmap= cmap,annot=True, square=True);

# %%
plt.figure(figsize=(20,12))
Days_of_week=sns.countplot(x=data['age'],data=data, hue ="DEATH_EVENT",palette = cols)
Days_of_week.set_title("Distribution Of Age", color="#774571")
# Out:
# Text(0.5, 1.0, 'Distribution Of Age')

# %%
# Boxen and swarm plot of some non binary features.
feature = ["age","creatinine_phosphokinase","ejection_fraction","platelets","serum_creatinine","serum_sodium", "time"]
for i in feature:
    plt.figure(figsize=(8,8))
    sns.swarmplot(x=data["DEATH_EVENT"], y=data[i], color="black", alpha=0.5)
    sns.boxenplot(x=data["DEATH_EVENT"], y=data[i], palette=cols)
    plt.show()
# Out:
# C:\Users\Prith\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 17.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.kdeplot(x=data["time"], y=data["age"], hue =data["DEATH_EVENT"], palette=cols)
# Out:
# <AxesSubplot:xlabel='time', ylabel='age'>

# %%
data.describe().T
# Out:
#                           count           mean           std      min  \
# age                       299.0      60.833893     11.894809     40.0
# anaemia                   299.0       0.431438      0.496107      0.0
# creatinine_phosphokinase  299.0     581.839465    970.287881     23.0
# diabetes                  299.0       0.418060      0.494067      0.0
# ejection_fraction         299.0      38.083612     11.834841     14.0
# high_blood_pressure       299.0       0.351171      0.478136      0.0
# platelets                 299.0  263358.029264  97804.236869  25100.0
# serum_creatinine          299.0       1.393880      1.034510      0.5
# serum_sodium              299.0     136.625418      4.412477    113.0
# sex                       299.0       0.648829      0.478136      0.0
# smoking                   299.0       0.321070      0.467670      0.0
# time                      299.0     130.260870     77.614208      4.0
# DEATH_EVENT               299.0       0.321070      0.467670      0.0
#
#                                25%       50%       75%       max
# age                           51.0      60.0      70.0      95.0
# anaemia                        0.0       0.0       1.0       1.0
# creatinine_phosphokinase     116.5     250.0     582.0    7861.0
# diabetes                       0.0       0.0       1.0       1.0
# ejection_fraction             30.0      38.0      45.0      80.0
# high_blood_pressure            0.0       0.0       1.0       1.0
# platelets                 212500.0  262000.0  303500.0  850000.0
# serum_creatinine               0.9       1.1       1.4       9.4
# serum_sodium                 134.0     137.0     140.0     148.0
# sex                            0.0       1.0       1.0       1.0
# smoking                        0.0       0.0       1.0       1.0
# time                          73.0     115.0     203.0     285.0
# DEATH_EVENT                    0.0       0.0       1.0       1.0

# %%
X=data.drop(["DEATH_EVENT"],axis=1)
y=data["DEATH_EVENT"]

# %%
col_names = list(X.columns)
s_scaler = preprocessing.StandardScaler()
X_df= s_scaler.fit_transform(X)
X_df = pd.DataFrame(X_df, columns=col_names)   
X_df.describe().T
# Out:
#                           count          mean       std       min       25%  \
# age                       299.0  5.265205e-16  1.001676 -1.754448 -0.828124
# anaemia                   299.0  3.594301e-16  1.001676 -0.871105 -0.871105
# creatinine_phosphokinase  299.0  3.713120e-18  1.001676 -0.576918 -0.480393
# diabetes                  299.0  1.113936e-16  1.001676 -0.847579 -0.847579
# ejection_fraction         299.0  3.341808e-18  1.001676 -2.038387 -0.684180
# high_blood_pressure       299.0 -4.841909e-16  1.001676 -0.735688 -0.735688
# platelets                 299.0  1.009969e-16  1.001676 -2.440155 -0.520870
# serum_creatinine          299.0 -2.227872e-18  1.001676 -0.865509 -0.478205
# serum_sodium              299.0 -8.627435e-16  1.001676 -5.363206 -0.595996
# sex                       299.0 -5.940993e-18  1.001676 -1.359272 -1.359272
# smoking                   299.0 -3.861645e-17  1.001676 -0.687682 -0.687682
# time                      299.0 -1.069379e-16  1.001676 -1.629502 -0.739000
#
#                                50%       75%       max
# age                      -0.070223  0.771889  2.877170
# anaemia                  -0.871105  1.147968  1.147968
# creatinine_phosphokinase -0.342574  0.000166  7.514640
# diabetes                 -0.847579  1.179830  1.179830
# ejection_fraction        -0.007077  0.585389  3.547716
# high_blood_pressure      -0.735688  1.359272  1.359272
# platelets                -0.013908  0.411120  6.008180
# serum_creatinine         -0.284552  0.005926  7.752020
# serum_sodium              0.085034  0.766064  2.582144
# sex                       0.735688  0.735688  0.735688
# smoking                  -0.687682  1.454161  1.454161
# time                     -0.196954  0.938759  1.997038

# %%
plt.figure(figsize=(20,10))
sns.boxenplot(data = X_df)
plt.xticks(rotation=90)
plt.show()

# %%
X_train, X_test, y_train,y_test = train_test_split(X_df,y,test_size=0.25,random_state=7)

# %%
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, 
    patience=20, 
    restore_best_weights=True)

model = Sequential()

model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.25))
model.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

history = model.fit(X_train, y_train, batch_size = 32, epochs = 500,callbacks=[early_stopping], validation_split=0.2)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 2s 41ms/step - loss: 0.6929 - accuracy: 0.6480 - val_loss: 0.6925 - val_accuracy: 0.6667
# Epoch 2/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6922 - accuracy: 0.6480 - val_loss: 0.6916 - val_accuracy: 0.6667
# Epoch 3/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6915 - accuracy: 0.6480 - val_loss: 0.6907 - val_accuracy: 0.6667
# Epoch 4/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6906 - accuracy: 0.6480 - val_loss: 0.6897 - val_accuracy: 0.6667
# Epoch 5/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6898 - accuracy: 0.6480 - val_loss: 0.6888 - val_accuracy: 0.6667
# Epoch 6/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6888 - accuracy: 0.6480 - val_loss: 0.6878 - val_accuracy: 0.6667
# Epoch 7/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6880 - accuracy: 0.6480 - val_loss: 0.6868 - val_accuracy: 0.6667
# Epoch 8/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6870 - accuracy: 0.6480 - val_loss: 0.6857 - val_accuracy: 0.6667
# Epoch 9/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6861 - accuracy: 0.6480 - val_loss: 0.6845 - val_accuracy: 0.6667
# Epoch 10/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6850 - accuracy: 0.6480 - val_loss: 0.6833 - val_accuracy: 0.6667
# Epoch 11/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6839 - accuracy: 0.6480 - val_loss: 0.6820 - val_accuracy: 0.6667
# Epoch 12/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6831 - accuracy: 0.6480 - val_loss: 0.6805 - val_accuracy: 0.6667
# Epoch 13/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6812 - accuracy: 0.6480 - val_loss: 0.6788 - val_accuracy: 0.6667
# Epoch 14/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6796 - accuracy: 0.6480 - val_loss: 0.6768 - val_accuracy: 0.6667
# Epoch 15/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6774 - accuracy: 0.6480 - val_loss: 0.6745 - val_accuracy: 0.6667
# Epoch 16/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6762 - accuracy: 0.6480 - val_loss: 0.6719 - val_accuracy: 0.6667
# Epoch 17/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6752 - accuracy: 0.6480 - val_loss: 0.6691 - val_accuracy: 0.6667
# Epoch 18/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6685 - accuracy: 0.6480 - val_loss: 0.6657 - val_accuracy: 0.6667
# Epoch 19/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6681 - accuracy: 0.6480 - val_loss: 0.6618 - val_accuracy: 0.6667
# Epoch 20/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6623 - accuracy: 0.6480 - val_loss: 0.6573 - val_accuracy: 0.6667
# Epoch 21/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6596 - accuracy: 0.6480 - val_loss: 0.6521 - val_accuracy: 0.6667
# Epoch 22/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6482 - accuracy: 0.6536 - val_loss: 0.6460 - val_accuracy: 0.6667
# Epoch 23/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6450 - accuracy: 0.6592 - val_loss: 0.6388 - val_accuracy: 0.6667
# Epoch 24/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6397 - accuracy: 0.6536 - val_loss: 0.6311 - val_accuracy: 0.6667
# Epoch 25/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6338 - accuracy: 0.6592 - val_loss: 0.6232 - val_accuracy: 0.6667
# Epoch 26/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6267 - accuracy: 0.6816 - val_loss: 0.6147 - val_accuracy: 0.6667
# Epoch 27/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6150 - accuracy: 0.7095 - val_loss: 0.6059 - val_accuracy: 0.6667
# Epoch 28/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6190 - accuracy: 0.7095 - val_loss: 0.5964 - val_accuracy: 0.7111
# Epoch 29/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6120 - accuracy: 0.7318 - val_loss: 0.5867 - val_accuracy: 0.7333
# Epoch 30/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6042 - accuracy: 0.6927 - val_loss: 0.5776 - val_accuracy: 0.7333
# Epoch 31/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5993 - accuracy: 0.7542 - val_loss: 0.5683 - val_accuracy: 0.7333
# Epoch 32/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5897 - accuracy: 0.7430 - val_loss: 0.5593 - val_accuracy: 0.7556
# Epoch 33/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5717 - accuracy: 0.7263 - val_loss: 0.5496 - val_accuracy: 0.7556
# Epoch 34/500
# 6/6 [==============================] - ETA: 0s - loss: 0.5842 - accuracy: 0.75 - 0s 11ms/step - loss: 0.5704 - accuracy: 0.7374 - val_loss: 0.5403 - val_accuracy: 0.8222
# Epoch 35/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5425 - accuracy: 0.7654 - val_loss: 0.5300 - val_accuracy: 0.8444
# Epoch 36/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5489 - accuracy: 0.7821 - val_loss: 0.5201 - val_accuracy: 0.8222
# Epoch 37/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5565 - accuracy: 0.7430 - val_loss: 0.5115 - val_accuracy: 0.8222
# Epoch 38/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5570 - accuracy: 0.7486 - val_loss: 0.5045 - val_accuracy: 0.8222
# Epoch 39/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5450 - accuracy: 0.7765 - val_loss: 0.4978 - val_accuracy: 0.8222
# Epoch 40/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5611 - accuracy: 0.7877 - val_loss: 0.4920 - val_accuracy: 0.8222
# Epoch 41/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5177 - accuracy: 0.7654 - val_loss: 0.4872 - val_accuracy: 0.8222
# Epoch 42/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5317 - accuracy: 0.8156 - val_loss: 0.4822 - val_accuracy: 0.8222
# Epoch 43/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4861 - accuracy: 0.8212 - val_loss: 0.4764 - val_accuracy: 0.8222
# Epoch 44/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5175 - accuracy: 0.8101 - val_loss: 0.4717 - val_accuracy: 0.8222
# Epoch 45/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5175 - accuracy: 0.7877 - val_loss: 0.4679 - val_accuracy: 0.8222
# Epoch 46/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5225 - accuracy: 0.8045 - val_loss: 0.4637 - val_accuracy: 0.8222
# Epoch 47/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5178 - accuracy: 0.7765 - val_loss: 0.4601 - val_accuracy: 0.8222
# Epoch 48/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5223 - accuracy: 0.7989 - val_loss: 0.4576 - val_accuracy: 0.8222
# Epoch 49/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5274 - accuracy: 0.7989 - val_loss: 0.4559 - val_accuracy: 0.8222
# Epoch 50/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5009 - accuracy: 0.7989 - val_loss: 0.4555 - val_accuracy: 0.8222
# Epoch 51/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5294 - accuracy: 0.7765 - val_loss: 0.4559 - val_accuracy: 0.8222
# Epoch 52/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5256 - accuracy: 0.7374 - val_loss: 0.4559 - val_accuracy: 0.8222
# Epoch 53/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4969 - accuracy: 0.8156 - val_loss: 0.4554 - val_accuracy: 0.8222
# Epoch 54/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5306 - accuracy: 0.8045 - val_loss: 0.4555 - val_accuracy: 0.8222
# Epoch 55/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4829 - accuracy: 0.8268 - val_loss: 0.4560 - val_accuracy: 0.8222
# Epoch 56/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4689 - accuracy: 0.8212 - val_loss: 0.4538 - val_accuracy: 0.8222
# Epoch 57/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5014 - accuracy: 0.8268 - val_loss: 0.4519 - val_accuracy: 0.8222
# Epoch 58/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4755 - accuracy: 0.8324 - val_loss: 0.4499 - val_accuracy: 0.8222
# Epoch 59/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4919 - accuracy: 0.8045 - val_loss: 0.4482 - val_accuracy: 0.8222
# Epoch 60/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4737 - accuracy: 0.7989 - val_loss: 0.4472 - val_accuracy: 0.8222
# Epoch 61/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4973 - accuracy: 0.8156 - val_loss: 0.4474 - val_accuracy: 0.8222
# Epoch 62/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5007 - accuracy: 0.8268 - val_loss: 0.4468 - val_accuracy: 0.8222
# Epoch 63/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4589 - accuracy: 0.8156 - val_loss: 0.4459 - val_accuracy: 0.8222
# Epoch 64/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4851 - accuracy: 0.7989 - val_loss: 0.4446 - val_accuracy: 0.8222
# Epoch 65/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4665 - accuracy: 0.8380 - val_loss: 0.4431 - val_accuracy: 0.8222
# Epoch 66/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4865 - accuracy: 0.8045 - val_loss: 0.4417 - val_accuracy: 0.8222
# Epoch 67/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4508 - accuracy: 0.8547 - val_loss: 0.4400 - val_accuracy: 0.8222
# Epoch 68/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4889 - accuracy: 0.8324 - val_loss: 0.4381 - val_accuracy: 0.8222
# Epoch 69/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5126 - accuracy: 0.8101 - val_loss: 0.4387 - val_accuracy: 0.8222
# Epoch 70/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4869 - accuracy: 0.8156 - val_loss: 0.4406 - val_accuracy: 0.8000
# Epoch 71/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4422 - accuracy: 0.8380 - val_loss: 0.4419 - val_accuracy: 0.8000
# Epoch 72/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5152 - accuracy: 0.7933 - val_loss: 0.4419 - val_accuracy: 0.8000
# Epoch 73/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4897 - accuracy: 0.7989 - val_loss: 0.4415 - val_accuracy: 0.8000
# Epoch 74/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4807 - accuracy: 0.8268 - val_loss: 0.4431 - val_accuracy: 0.8000
# Epoch 75/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4568 - accuracy: 0.8045 - val_loss: 0.4437 - val_accuracy: 0.8000
# Epoch 76/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5030 - accuracy: 0.8324 - val_loss: 0.4427 - val_accuracy: 0.8000
# Epoch 77/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4631 - accuracy: 0.8492 - val_loss: 0.4420 - val_accuracy: 0.8000
# Epoch 78/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4881 - accuracy: 0.8324 - val_loss: 0.4407 - val_accuracy: 0.8000
# Epoch 79/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5140 - accuracy: 0.8101 - val_loss: 0.4399 - val_accuracy: 0.8222
# Epoch 80/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4626 - accuracy: 0.8547 - val_loss: 0.4414 - val_accuracy: 0.8000
# Epoch 81/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4389 - accuracy: 0.8156 - val_loss: 0.4428 - val_accuracy: 0.8000
# Epoch 82/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4370 - accuracy: 0.8492 - val_loss: 0.4429 - val_accuracy: 0.8000
# Epoch 83/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.5055 - accuracy: 0.8101 - val_loss: 0.4441 - val_accuracy: 0.8000
# Epoch 84/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4602 - accuracy: 0.8156 - val_loss: 0.4450 - val_accuracy: 0.8000
# Epoch 85/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4388 - accuracy: 0.8212 - val_loss: 0.4465 - val_accuracy: 0.8000
# Epoch 86/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4231 - accuracy: 0.8603 - val_loss: 0.4470 - val_accuracy: 0.8000
# Epoch 87/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4470 - accuracy: 0.8324 - val_loss: 0.4481 - val_accuracy: 0.8000
# Epoch 88/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4478 - accuracy: 0.8212 - val_loss: 0.4501 - val_accuracy: 0.8000

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy', val_accuracy*100))
# Out:
# val_accuracy: 76.44%

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#6daa9f", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#774571", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %% [markdown]
# **Plotting training and validation accuracy over epochs**

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#800080", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']], "#FF7F50", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
np.set_printoptions()

# %%
plt.subplots(figsize=(12,8))
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot = True, annot_kws = {'size':15})
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.86        57
#            1       0.55      0.61      0.58        18
#
#     accuracy                           0.79        75
#    macro avg       0.71      0.73      0.72        75
# weighted avg       0.80      0.79      0.79        75
